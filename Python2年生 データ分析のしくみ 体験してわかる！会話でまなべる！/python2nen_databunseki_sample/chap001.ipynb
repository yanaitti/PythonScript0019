# %% [markdown]
# # 第1章 データ分析って何？

# %% [markdown]
# ## 04 Jupyter Notebookの使い方

# %% [markdown]
# リスト1.1

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# リスト1.2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([0,2,1,3])
plt.show()

# %% [markdown]
# リスト1.3

# %% [markdown]
# # 説明文
# プログラムの説明です。
